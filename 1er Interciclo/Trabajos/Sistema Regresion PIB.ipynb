# %% [markdown]
# ## Enunciado
# #### Generar un sistema de regresión que permita predecir el comportamiento del PIB del Ecuador para ello tomar los datos que están cargados dentro del AVAC solo del Ecuador, generar un cuaderno de python e incluir las secciones de Introducción, Resultados, Opinión, Conclusiones y Bibliografía.
#
# * El producto interior bruto (PIB) es un indicador económico que refleja el valor monetario de todos los bienes y servicios finales producidos por un país o región en un determinado periodo de tiempo, normalmente un año. Se utiliza para medir la riqueza que genera un país. También se conoce como producto bruto interno (PBI).
# * Finalmente analizar con el gasto y el COVID-19 dentro del Ecuador y realizar un análisis con respecto a la actualidad y cambio de gobierno del país.

# %% [markdown]
# ## Introduccion
#
# Se realiza una comparación de modelos, lineal, polilnomico,logísticos y exponenciales aplicados a la infección por el virus Covid-19 y el PIB.
#
# Se realiza un análisis matemático simple del comportamiento  del PIB del Ecuador en  Python y  modelos de regresion lineal para comprender mejor el comportamiento del PIB.
#
# Se crea modelos de series temporales del número total de personas infectadas hasta la fecha (es decir, las personas realmente infectadas más las personas que han sido infectadas). Estos modelos tienen parámetros , que se estimarán por ajuste de curva.

# %% [markdown]
# ## Desarrollo

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = pd.read_excel (r'C:/Users/jhonn/OneDrive/Documentos/Simulacion/1er Interciclo/Trabajos/API_NE.EXP.GNFS.ZS_DS2_es_excel_v2_2252968.xls') 
data
# Out:
#            Data Source Indicadores del desarrollo mundial  \
# 0    Last Updated Date                2021-03-19 00:00:00
# 1                  NaN                                NaN
# 2         Country Name                       Country Code
# 3                Aruba                                ABW
# 4           Afganistán                                AFG
# ..                 ...                                ...
# 262             Kosovo                                XKX
# 263    Yemen, Rep. del                                YEM
# 264          Sudáfrica                                ZAF
# 265             Zambia                                ZMB
# 266           Zimbabwe                                ZWE
#
#                                           Unnamed: 2      Unnamed: 3  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2                                     Indicator Name  Indicator Code
# 3    Exportaciones de bienes y servicios (% del PIB)  NE.EXP.GNFS.ZS
# 4    Exportaciones de bienes y servicios (% del PIB)  NE.EXP.GNFS.ZS
# ..                                               ...             ...
# 262  Exportaciones de bienes y servicios (% del PIB)  NE.EXP.GNFS.ZS
# 263  Exportaciones de bienes y servicios (% del PIB)  NE.EXP.GNFS.ZS
# 264  Exportaciones de bienes y servicios (% del PIB)  NE.EXP.GNFS.ZS
# 265  Exportaciones de bienes y servicios (% del PIB)  NE.EXP.GNFS.ZS
# 266  Exportaciones de bienes y servicios (% del PIB)  NE.EXP.GNFS.ZS
#
#       Unnamed: 4   Unnamed: 5   Unnamed: 6   Unnamed: 7   Unnamed: 8  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2    1960.000000  1961.000000  1962.000000  1963.000000  1964.000000
# 3            NaN          NaN          NaN          NaN          NaN
# 4       4.132233     4.453443     4.878051     9.171601     8.888893
# ..           ...          ...          ...          ...          ...
# 262          NaN          NaN          NaN          NaN          NaN
# 263          NaN          NaN          NaN          NaN          NaN
# 264    29.550915    29.323968    29.406919    28.613876    27.435897
# 265          NaN          NaN          NaN          NaN          NaN
# 266          NaN          NaN          NaN          NaN          NaN
#
#       Unnamed: 9  ...  Unnamed: 55  Unnamed: 56  Unnamed: 57  Unnamed: 58  \
# 0            NaN  ...          NaN          NaN          NaN          NaN
# 1            NaN  ...          NaN          NaN          NaN          NaN
# 2    1965.000000  ...  2011.000000  2012.000000  2013.000000  2014.000000
# 3            NaN  ...    67.813322    65.241349    76.509512    77.555556
# 4      11.258279  ...          NaN          NaN          NaN          NaN
# ..           ...  ...          ...          ...          ...          ...
# 262          NaN  ...    23.630699    23.256504    21.929561    22.502021
# 263          NaN  ...          NaN          NaN          NaN          NaN
# 264    25.704051  ...    30.460941    29.723879    30.971341    31.468645
# 265          NaN  ...    40.471223    40.082911    40.482717    38.822290
# 266          NaN  ...    34.800802    25.163254    21.987759    20.930146
#
#      Unnamed: 59  Unnamed: 60  Unnamed: 61  Unnamed: 62  Unnamed: 63  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2    2015.000000  2016.000000  2017.000000  2018.000000  2019.000000
# 3      73.517030    71.294029    73.332115          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 262    21.937317    23.698127    26.649932    26.431364    29.215526
# 263          NaN          NaN          NaN          NaN          NaN
# 264    30.152888    30.580928    29.627669    29.907083    29.853839
# 265    37.138526    35.324676    34.992858    37.957353    34.636161
# 266    19.160176    19.943532    19.658023    19.000609          NaN
#
#      Unnamed: 64
# 0            NaN
# 1            NaN
# 2         2020.0
# 3            NaN
# 4            NaN
# ..           ...
# 262          NaN
# 263          NaN
# 264          NaN
# 265          NaN
# 266          NaN
#
# [267 rows x 65 columns]

# %%
df = data.T
df.columns = data['Data Source']
df = df[2:]
